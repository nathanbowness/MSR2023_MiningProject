# %% [markdown]
# Using the filtered projects results returned from MongoDB. We should be able to collect all the READMEs and Release Information.
#
# First get the users github token:

# %%
from github import Github
import getpass
import time
import pandas as pd
import csv
import langdetect
import base64
import os
import json

g = Github(getpass.getpass("Enter access token:"), per_page=100)

# %% [markdown]
# Make directories to store the readmes and releases for each language if they don't exist.

# %%
languages = ["python","go", "java", "ruby",]

readme_folder = "readmes"
releases_folder = "releases"

if not os.path.exists(readme_folder):
    os.makedirs(readme_folder)

if not os.path.exists(releases_folder):
    os.makedirs(releases_folder)

for language in languages:

    language_readme_folder = f'{readme_folder}/{language}'
    if not os.path.exists(language_readme_folder):
        os.makedirs(language_readme_folder)

    language_releases_folder = f'{releases_folder}/{language}'
    if not os.path.exists(language_releases_folder):
        os.makedirs(language_releases_folder)

# %% [markdown]
# With the github token, collect the READMEs, and the Releases for each repository.
# Collect the project README first, then try to collect the Release information.
# Write the results back to the project_details/results folder. Storing the results there will let us do some analysis later if needed.

# %%
project_details_folder = "project_details"

for language in languages:

    language_readme_folder = f'{readme_folder}/{language}'
    language_releases_folder = f'{releases_folder}/{language}'
 
    f = open(f'{project_details_folder}/filtered/{language}_projects_filtered.json')
    projects_data = json.load(f)

    
    print(f"Retrieving the readme files for {len(projects_data)} repositories in {language}...")
    
    collectedReadmes = 0
    collectedReleases = 0
    for project in projects_data:

        projectId = project["ProjectID"]
        projectOwner = projectId.split('/')[0]
        projectName = projectId.split('/')[1]

        # Folders to store the projects readme & releases
        readme_file = f"{language_readme_folder}/{projectOwner}_{projectName}_readme.md"
        release_file = f"{language_releases_folder}/{projectOwner}_{projectName}_releases.jsonl"

        if os.path.exists(readme_file) or os.path.exists(release_file):
            continue # continue to next project, we've already collected this projects info

        try:
            repo = g.get_repo(projectId)
        except Exception as e:
            print(f"{projectId}: {e}")
        
        # Try to collect the readme information
        time.sleep(0.25)
        try:
            readme = base64.b64decode(repo.get_readme()._rawData["content"].encode()).decode("UTF-8")
            with open(readme_file, "w", encoding="utf-8") as file:
                file.write(readme)
            collectedReadmes += 1
        except Exception as e:
            print(f"{projectId}: {e}")
            time.sleep(1)
        
        # Try to collect the release information
        time.sleep(0.25)
        try:
            releases = repo.get_releases()
            
            if releases.totalCount >= 1:
                with open(release_file, "w", encoding="utf-8") as file:
                    for release in releases:
                        file.write(json.dumps(release.raw_data) + "\n")
                collectedReleases += 1
        except Exception as e:
            print(f"{projectId}: {e}")
            if os.path.exists(release_file):
                os.remove(release_file) 
            time.sleep(1)
   
    print(f"{collectedReadmes} new readme files were collected for {language} projects.")
    print(f"{collectedReleases} new release files were collected for {language} projects.")
# Out:
# Retrieving the readme files for 4663 repositories in python...
# google/eng-edu: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# mehulsingh10/Age-Transformation-Synthesis: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# tensorflow/workshops: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# LibreOffice/mso-dumper: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# cyyself/yaffs2: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# cdemu/cdemu: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros/common_msgs: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros-visualization/visualization_tutorials: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# blankon-packages/blankon-wallpapers: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# mkc2/avr-libc: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros/genmsg: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# calthoff/self_taught: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Zeus-OS/scripts: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# opensemanticsearch/open-semantic-etl: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# UlisesLuzius/ImageProcessingPipeline: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# vertelab/odoo-edi: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# RobertCNelson/boot-scripts: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# hseos/hseos-course: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# linuxmint/mintsystem: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros/actionlib: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# TwentyBN/GulpIO: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest"}
# TwentyBN/GulpIO: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# mit-racecar/vesc: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Artfunkel/BlenderSourceTools: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# littlesat/skin-PLiHD: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Loki-Astari/vera-plusplus: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# libretro/snes9x2010: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# osmocom/gr-fosphor: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# tamland/xbmc-addon-nrk: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# MotorolaMobilityLLC/motorola-kernel: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# andrewguertin/ogr2osm: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# BCMM/xbmc-addon-service-watchedlist: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros/roscpp_core: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ros-perception/calibration: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# GNOME/gnome-schedule: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository"}
# GNOME/gnome-schedule: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# j1z0/vim-config: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ethanfurman/dbf: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# hiromi-mi/courgette: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# 0 new readme files were collected for python projects.
# 0 new release files were collected for python projects.
# Retrieving the readme files for 927 repositories in go...
# GoesToEleven/golang-project: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# c-rindi/geras: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository"}
# c-rindi/geras: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# 0 new readme files were collected for go projects.
# 0 new release files were collected for go projects.
# Retrieving the readme files for 2358 repositories in java...
# JoshitaA/Bitcoin-Ticker: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# fatime116/summer2020_b20-1: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# prestodb/presto-hadoop-apache2: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# prestosql/presto-hive-apache: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# onlineTrainingguy/DevOpsNotes: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Anuken/CoreBot: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# kuydo3912/myhome: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# TheMuppets/proprietary_vendor_htc: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# ptew/.dot_files: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# DTCproto/ws-plugin-android: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository"}
# DTCproto/ws-plugin-android: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# jrbudda/Sentry: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# viruscamp/unluac1: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# udacity/kotlin-notepad: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# fdesque/ws-cleanup-plugin: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# apache/commons-digester: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# MinecraftForge/EventBus: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# jboss-remoting/jboss-remoting: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# jesperpedersen/tattletale: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# tackley/dbdeploy: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# androidsoft-org/androidsoft-coloring: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Evolution-X/packages_apps_Evolver: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# dollybu/newDB: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# google/jsontoken: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# LineageOS/android_packages_apps_SoundRecorder: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# TheMuppets/proprietary_vendor_bq: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# Aishwary1/jaxmpp: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# 3lou401/algorithmbasic2020: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# burstlam/device_samsung_maguro: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# dadowl/townychat: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# derp11/betterchairs: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# QuiltMC/matcher: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# openhab/org.openhab.binding.zigbee: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# TheMuppets/proprietary_vendor_wileyfox: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# xnio/xnio: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# wk66/goos-code: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# how2j/hellogit: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# beamboy94/Spring_Fine: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# chaupal/jxse: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# LineageOS/android_packages_apps_PhoneCommon: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# cmostuor/jnlua: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# eiGor/Stud: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# SpoutDev/Vanilla: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# apache/commons-chain: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# weld/api: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# 0 new readme files were collected for java projects.
# 0 new release files were collected for java projects.
# Retrieving the readme files for 1141 repositories in ruby...
# mattn/mruby-thread: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# JustQyx/vimrc: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-a-repository-readme"}
# 0 new readme files were collected for ruby projects.
# 0 new release files were collected for ruby projects.
